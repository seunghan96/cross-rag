# %%
import os, re, glob
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:.4f}'.format
os.chdir('/home/seunghan.lee/workspace/cross-rag/results')
results_dir = Path('./forecast_evaluation')
# results_dir = Path('./forecast_evaluation_OLD')
print(f"Results directory: {results_dir.absolute()}")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Results directory: /home/seunghan.lee/workspace/ts-rag/results/forecast_evaluation

# %%
def parse_result_file(file_path):
    results_dict = {}  # Use a dictionary to keep only the last result per dataset
    with open(file_path, 'r') as f:
        lines = f.readlines()
    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if not line:
            i += 1
            continue
        if '_zeroshot_' in line:
            dataset = line.split('_zeroshot_')[0]
            if i + 1 < len(lines):
                metric_line = lines[i + 1].strip()
                mse_match = re.search(r'mse:([\d.]+)', metric_line)
                mae_match = re.search(r'mae:([\d.]+)', metric_line)
                if mse_match and mae_match:
                    # Update dictionary - later results will overwrite earlier ones
                    results_dict[dataset] = {
                        'dataset': dataset,
                        'mse': float(mse_match.group(1)),
                        'mae': float(mae_match.group(1))
                    }
                i += 2
            else:
                i += 1
        else:
            i += 1
    return list(results_dict.values())


def parse_filename(filename):
    """Parse filename to extract configuration (legacy + TabPFN variants)."""
    # Allow TabPFN suffix chunk after "_TabPFN" (e.g., _TabPFN_gate, _TabPFN_multiscale_scales4-8-16)
    pattern = r'zeroshot_(\w+)_lb(\d+)_(.+?)_k(\d+)(?:_(soft(?:v[12]|Y(?:enc)?_v[12]))_temp([\d\.]+)|_TabPFN([\w\.-]*))?\.txt'
    match = re.match(pattern, filename)
    if match:
        backbone, lookback, similarity_space, top_k, soft_variant, temperature, tabpfn_suffix = match.groups()
        if soft_variant:
            variant = soft_variant
        elif tabpfn_suffix is not None:
            suffix = tabpfn_suffix.lstrip('_') if tabpfn_suffix else ''
            variant = 'TabPFN' + (f'_{suffix}' if suffix else '')
        else:
            variant = None
        return {
            'backbone': backbone,
            'lookback': int(lookback),
            'similarity_space': similarity_space,
            'top_k': int(top_k),
            'variant': variant,
            'temperature': float(temperature) if temperature else None,
        }
    return None

# %%
# Load all result files
result_files = glob.glob(str(results_dir / 'zeroshot_*.txt'))
# print(f"Found {len(result_files)} result files")
# print(len(result_files))
# result_files = [x for x in result_files if 'dualhead' not in x]
# print(len(result_files))
# result_files = [x for x in result_files if 'Z' in x]
# result_files = [x for x in result_files if 'soft' not in x]
# result_files = [x for x in result_files if 'TabPFN' not in x]
# print(len(result_files))

# %%
#os.listdir('forecast_evaluation_OLD')

# %%
# #result_files
# import shutil
 
# from_file_path = './forecast_evaluation_OLD/zeroshot_Chronos_lb512_Z_k20.txt' # file to copy
# to_file_path = './forecast_evaluation/zeroshot_Chronos_lb512_Z_k20.txt' # copy location and file name
# shutil.copyfile(from_file_path, to_file_path)

# %%
all_results = []
for file_path in result_files:
    filename = os.path.basename(file_path)
    config = parse_filename(filename)
    if config is None:
        print(f"Warning: Could not parse filename: {filename}")
        continue
    for result in parse_result_file(file_path):
        all_results.append({**config, **result})

# Create DataFrame
df = pd.DataFrame(all_results)
print(f"Total records: {len(df)}")
# Out:
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k10_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k1_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k3_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k1_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k3_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha5.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k5_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k5_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha10.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k15_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k15_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k20_random.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k20_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha20.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha75.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha50.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k20_alpha75.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k10_alpha50.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k10_alpha75.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k5_alpha25.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k15_alpha50.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z-random_k10_random2.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k15_alpha75.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k10_alpha20.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k20_alpha50.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k10_alpha25.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k15_alpha20.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k15_alpha25.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k20_alpha20.txt
# Warning: Could not parse filename: zeroshot_Chronos_lb512_Z_k20_alpha25.txt
# Total records: 9949

# %%
# Fill missing configs for grouping
# - variant: baseline when None
# - temperature: keep numeric; use string 'NA' for missing to keep pivot columns

df_filled = df.copy()
df_filled['variant'] = df_filled['variant'].fillna('baseline')
df_filled['temperature'] = df_filled['temperature'].fillna('NA')

# %%
# Pivot tables: rows = model settings, cols = datasets
index_cols = ['backbone', 'lookback', 'similarity_space', 'top_k', 'variant', 'temperature']

pivot_mse = df_filled.pivot_table(index=index_cols, columns='dataset', values='mse')
pivot_mae = df_filled.pivot_table(index=index_cols, columns='dataset', values='mae')
########################################################
########################################################
########################################################
# if 'electricity' in pivot_mse.columns:
#     pivot_mse = pivot_mse.drop(columns=['electricity'])
# if 'electricity' in pivot_mae.columns:
#     pivot_mae = pivot_mae.drop(columns=['electricity'])
########################################################
########################################################
########################################################
pivot_mse['Avg'] = pivot_mse.mean(axis=1)
pivot_mae['Avg'] = pivot_mae.mean(axis=1)
# Optional: sort columns and index for readability
pivot_mse = pivot_mse.sort_index(axis=1).sort_index()
pivot_mae = pivot_mae.sort_index(axis=1).sort_index()

# %%
filtered_ours = pivot_mse.loc[
    ##############################################################################################################################
    pivot_mse.index.get_level_values('variant').str.contains('TabPFN_dualhead_R_as_key_l0.7', case=False) & 
    ##############################################################################################################################    
    pivot_mse.index.get_level_values('similarity_space').str.contains('X-cosine-norm', case=False)   
]

filtered_ours = filtered_ours.loc[~filtered_ours.index.get_level_values('variant').str.contains('pretrain', case=False)]

# filtered.sort_values('Avg').round(4)
filtered_ours = filtered_ours.sort_values(['backbone','lookback','similarity_space','top_k'])#.round(4)
filtered_ours = filtered_ours.reset_index()
filtered_ours = filtered_ours[filtered_ours['variant']=='TabPFN_dualhead_R_as_key_l0.7']
filtered_ours
# Out:
# dataset          backbone  lookback similarity_space  top_k  \
# 0                 Chronos       512    X-cosine-norm      1
# 1                 Chronos       512    X-cosine-norm      2
# 2                 Chronos       512    X-cosine-norm      3
# 3                 Chronos       512    X-cosine-norm      4
# 4                 Chronos       512    X-cosine-norm      5
# 11                Chronos       512    X-cosine-norm      6
# 12                Chronos       512    X-cosine-norm      7
# 13                Chronos       512    X-cosine-norm      8
# 14                Chronos       512    X-cosine-norm      9
# 15                Chronos       512    X-cosine-norm     10
# 22                Chronos       512    X-cosine-norm     11
# 23                Chronos       512    X-cosine-norm     12
# 24                Chronos       512    X-cosine-norm     13
# 25                Chronos       512    X-cosine-norm     14
# 26                Chronos       512    X-cosine-norm     15
# 33                Chronos       512    X-cosine-norm     16
# 34                Chronos       512    X-cosine-norm     17
# 35                Chronos       512    X-cosine-norm     18
# 36                Chronos       512    X-cosine-norm     19
# 37                Chronos       512    X-cosine-norm     20
# 54                 MOMENT       512    X-cosine-norm      3
# 55                 MOMENT       512    X-cosine-norm      6
# 56                 MOMENT       512    X-cosine-norm     12
# 57                 MOMENT       512    X-cosine-norm     15
# 58       transfer_Chronos       512    X-cosine-norm     15
#
# dataset                        variant temperature    Avg  ETTh1  ETTh2  \
# 0        TabPFN_dualhead_R_as_key_l0.7          NA 0.1953 0.3513 0.2457
# 1        TabPFN_dualhead_R_as_key_l0.7          NA 0.1944 0.3476 0.2464
# 2        TabPFN_dualhead_R_as_key_l0.7          NA 0.1940 0.3466 0.2467
# 3        TabPFN_dualhead_R_as_key_l0.7          NA 0.1938 0.3462 0.2466
# 4        TabPFN_dualhead_R_as_key_l0.7          NA 0.1937 0.3461 0.2468
# 11       TabPFN_dualhead_R_as_key_l0.7          NA 0.1936 0.3465 0.2474
# 12       TabPFN_dualhead_R_as_key_l0.7          NA 0.1937 0.3449 0.2484
# 13       TabPFN_dualhead_R_as_key_l0.7          NA 0.1934 0.3449 0.2480
# 14       TabPFN_dualhead_R_as_key_l0.7          NA 0.1932 0.3444 0.2469
# 15       TabPFN_dualhead_R_as_key_l0.7          NA 0.1933 0.3451 0.2467
# 22       TabPFN_dualhead_R_as_key_l0.7          NA 0.1933 0.3451 0.2465
# 23       TabPFN_dualhead_R_as_key_l0.7          NA 0.1930 0.3449 0.2462
# 24       TabPFN_dualhead_R_as_key_l0.7          NA 0.1930 0.3451 0.2462
# 25       TabPFN_dualhead_R_as_key_l0.7          NA 0.1927 0.3441 0.2451
# 26       TabPFN_dualhead_R_as_key_l0.7          NA 0.1924 0.3424 0.2467
# 33       TabPFN_dualhead_R_as_key_l0.7          NA 0.1934 0.3439 0.2470
# 34       TabPFN_dualhead_R_as_key_l0.7          NA 0.1928 0.3444 0.2467
# 35       TabPFN_dualhead_R_as_key_l0.7          NA 0.1926 0.3436 0.2460
# 36       TabPFN_dualhead_R_as_key_l0.7          NA 0.1932 0.3462 0.2448
# 37       TabPFN_dualhead_R_as_key_l0.7          NA 0.1934 0.3459 0.2452
# 54       TabPFN_dualhead_R_as_key_l0.7          NA 0.2674 0.4392 0.2746
# 55       TabPFN_dualhead_R_as_key_l0.7          NA 0.2685 0.4293 0.2806
# 56       TabPFN_dualhead_R_as_key_l0.7          NA 0.2612 0.4300 0.2761
# 57       TabPFN_dualhead_R_as_key_l0.7          NA 0.2611 0.4194 0.2717
# 58       TabPFN_dualhead_R_as_key_l0.7          NA 0.2555 0.3414 0.2456
#
# dataset  ETTm1  ETTm2  electricity  exchange_rate  weather
# 0       0.2986 0.1441       0.1158         0.0656   0.1462
# 1       0.2976 0.1435       0.1145         0.0652   0.1458
# 2       0.2966 0.1433       0.1143         0.0648   0.1454
# 3       0.2956 0.1434       0.1141         0.0652   0.1453
# 4       0.2945 0.1435       0.1141         0.0653   0.1455
# 11      0.2937 0.1432       0.1139         0.0653   0.1453
# 12      0.2940 0.1437       0.1143         0.0655   0.1452
# 13      0.2925 0.1436       0.1139         0.0658   0.1449
# 14      0.2928 0.1436       0.1139         0.0658   0.1448
# 15      0.2922 0.1425       0.1142         0.0675   0.1447
# 22      0.2928 0.1436       0.1139         0.0665   0.1450
# 23      0.2912 0.1434       0.1141         0.0663   0.1450
# 24      0.2913 0.1432       0.1140         0.0663   0.1447
# 25      0.2905 0.1438       0.1139         0.0673   0.1444
# 26      0.2901 0.1435       0.1138         0.0655   0.1450
# 33      0.2929 0.1438       0.1138         0.0677   0.1450
# 34      0.2909 0.1434       0.1139         0.0658   0.1448
# 35      0.2895 0.1440       0.1138         0.0666   0.1446
# 36      0.2909 0.1445       0.1140         0.0673   0.1446
# 37      0.2929 0.1442       0.1141         0.0662   0.1454
# 54      0.4373 0.1864       0.2025         0.1500   0.1817
# 55      0.4264 0.1849       0.1923         0.1820   0.1838
# 56      0.4095 0.1830       0.1914         0.1604   0.1782
# 57      0.4231 0.1853       0.1939         0.1567   0.1773
# 58      0.2895 0.1453          NaN            NaN      NaN

# %%
filtered_base = pivot_mse.loc[
    ##############################################################################################################################
#     pivot_mse.index.get_level_values('variant').str.contains('TabPFN_dualhead_R_as_key_l0.6', case=False) & 
    ##############################################################################################################################    
    pivot_mse.index.get_level_values('similarity_space').str.contains('Z', case=False)   
]

filtered_base = filtered_base.loc[~filtered_base.index.get_level_values('variant').str.contains('pretrain', case=False)]

# filtered.sort_values('Avg').round(4)
filtered_base = filtered_base.sort_values(['backbone','lookback','similarity_space','top_k'])#.round(4)
filtered_base = filtered_base.reset_index()
filtered_base
# Out:
# dataset                   backbone  lookback similarity_space  top_k  \
# 0                          Chronos       512                Z      1
# 1                          Chronos       512                Z      2
# 2                          Chronos       512                Z      3
# 3                          Chronos       512                Z      4
# 4                          Chronos       512                Z      5
# 5                          Chronos       512                Z      6
# 6                          Chronos       512                Z      7
# 7                          Chronos       512                Z      8
# 8                          Chronos       512                Z      9
# 9                          Chronos       512                Z     10
# 10                         Chronos       512                Z     11
# 11                         Chronos       512                Z     12
# 12                         Chronos       512                Z     13
# 13                         Chronos       512                Z     14
# 14                         Chronos       512                Z     15
# 15                         Chronos       512                Z     15
# 16                         Chronos       512                Z     15
# 17                         Chronos       512                Z     15
# 18                         Chronos       512                Z     16
# 19                         Chronos       512                Z     17
# 20                         Chronos       512                Z     18
# 21                         Chronos       512                Z     19
# 22                         Chronos       512                Z     20
# 23       transfer_baseline_Chronos       512                Z      5
#
# dataset                        variant temperature    Avg  ETTh1  ETTh2  \
# 0                             baseline          NA 0.1966 0.3565 0.2395
# 1                             baseline          NA 0.1975 0.3569 0.2380
# 2                             baseline          NA 0.1981 0.3597 0.2380
# 3                             baseline          NA 0.2011 0.3564 0.2406
# 4                             baseline          NA 0.1967 0.3574 0.2406
# 5                             baseline          NA 0.1968 0.3571 0.2419
# 6                             baseline          NA 0.1953 0.3559 0.2431
# 7                             baseline          NA 0.1975 0.3586 0.2367
# 8                             baseline          NA 0.2004 0.3563 0.2376
# 9                             baseline          NA 0.1964 0.3566 0.2359
# 10                            baseline          NA 0.1971 0.3595 0.2459
# 11                            baseline          NA 0.1974 0.3564 0.2417
# 12                            baseline          NA 0.1970 0.3563 0.2468
# 13                            baseline          NA 0.2013 0.3566 0.2483
# 14       TabPFN_dualhead_R_as_key_l0.6          NA 0.1942 0.3458 0.2468
# 15       TabPFN_dualhead_R_as_key_l0.7          NA 0.1933 0.3469 0.2445
# 16       TabPFN_dualhead_R_as_key_l0.8          NA 0.1937 0.3464 0.2437
# 17                            baseline          NA 0.2102 0.3583 0.2406
# 18                            baseline          NA 0.1962 0.3569 0.2384
# 19                            baseline          NA 0.2020 0.3580 0.2391
# 20                            baseline          NA 0.1961 0.3579 0.2455
# 21                            baseline          NA 0.2055 0.3593 0.2453
# 22                            baseline          NA 0.1978 0.3572 0.2372
# 23                            baseline          NA 0.3574 0.3574    NaN
#
# dataset  ETTm1  ETTm2  electricity  exchange_rate  weather
# 0       0.2940 0.1480       0.1124         0.0724   0.1532
# 1       0.2967 0.1493       0.1123         0.0783   0.1510
# 2       0.2943 0.1518       0.1121         0.0768   0.1541
# 3       0.2991 0.1561       0.1122         0.0887   0.1544
# 4       0.2975 0.1470       0.1123         0.0706   0.1513
# 5       0.2978 0.1491       0.1123         0.0709   0.1487
# 6       0.2948 0.1463       0.1122         0.0662   0.1485
# 7       0.2974 0.1488       0.1120         0.0796   0.1494
# 8       0.2989 0.1513       0.1124         0.0931   0.1530
# 9       0.2945 0.1503       0.1123         0.0728   0.1524
# 10      0.2982 0.1468       0.1123         0.0680   0.1492
# 11      0.2963 0.1516       0.1125         0.0714   0.1518
# 12      0.2988 0.1458       0.1125         0.0661   0.1525
# 13      0.2984 0.1538       0.1124         0.0821   0.1574
# 14      0.2973 0.1437       0.1152         0.0661   0.1447
# 15      0.2943 0.1438       0.1135         0.0656   0.1446
# 16      0.2959 0.1444       0.1126         0.0667   0.1462
# 17      0.2993 0.1617       0.1122         0.1424   0.1567
# 18      0.2988 0.1456       0.1125         0.0718   0.1496
# 19      0.3092 0.1522       0.1128         0.0720   0.1705
# 20      0.2970 0.1457       0.1125         0.0663   0.1478
# 21      0.3055 0.1654       0.1122         0.0885   0.1624
# 22      0.2939 0.1513       0.1123         0.0710   0.1617
# 23         NaN    NaN          NaN            NaN      NaN

# %%
#filtered_ours['Avg'].values[:15].round(4)[[0,2,4,9,14]]
filtered_ours['Avg'].values[:15].round(3)[[2,5,8,11,14]]
# Out:
# array([0.194, 0.194, 0.193, 0.193, 0.192])

# %%
#[0.1944, 0.1938, 0.2161, 0.2078, 0.1932]

filtered_base['Avg'].values[:15].round(4)[[0,2,4,9,14]]
filtered_base['Avg'].values[:15].round(3)[[2,5,8,11,14]]
# Out:
# array([0.198, 0.197, 0.2  , 0.197, 0.194])

# %%
from_ = 0
to_ = 14
plt.plot(range(from_ + 1, to_ +1),filtered_base['Avg'][from_:to_],linestyle='solid',color="tab:red",marker='o',label='(Base) w/o Cross-Att.')
plt.plot(range(from_ + 1, to_ +1),filtered_ours['Avg'][from_:to_],linestyle='solid',color="tab:green",marker='o',label='(Ours) w/ Cross-Att.')
plt.title('Performance across 7 datasets',fontsize=24,pad=10)
plt.legend(fontsize=14,loc='upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r'# of retrieved samples ($k$)', fontsize=20,labelpad=5)
plt.ylabel(r'Avg. MSE', fontsize=20,labelpad=5)
# ax[0,0].plot(df1['X'],df1['Y'],color='blue',linestyle='solid',marker='o')
# ax[0,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dotted',marker='o')
# ax[1,0].plot(df1['X'],df1['Y'],color='blue',linestyle='dashed',marker='o')
# ax[1,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dashdot',marker='o')
########################################################################
# plt.tight_layout()
# plt.show()
########################################################################
plt.tight_layout()
SAVE_PATH = '/home/seunghan.lee/workspace/experiments/figures'
fn = "01.motivation_K.pdf"
fn = os.path.join(SAVE_PATH,fn)
plt.savefig(fn, bbox_inches="tight")
plt.show()

# %%
#plt.plot([3,6,9,12,15],filtered_base['Avg'].values[[2,5,8,11,14]],linestyle='solid',color="tab:red",marker='o',label='(Base) w/o Cross-Att.')
#plt.plot([3,6,9,12,15],filtered_ours['Avg'].values[[2,5,8,11,14]],linestyle='solid',color="tab:green",marker='o',label='(Ours) w/ Cross-Att.')
plt.plot([2,4,6,8,10,12,14],filtered_base['Avg'].values[[1,3,5,7,9,11,13]],linestyle='solid',color="tab:red",marker='o',label='(Base) w/o Cross-Attention',markersize=11)
plt.plot([2,4,6,8,10,12,14],filtered_ours['Avg'].values[[1,3,5,7,9,11,13]],linestyle='solid',color="tab:blue",marker='o',label='(Ours) w/ Cross-Attention',markersize=11)
plt.title('Performance across 7 datasets',fontsize=24,pad=10)
#plt.legend(fontsize=18,loc='upper left')
plt.legend(fontsize=16,loc=(0.23,0.2))
plt.xticks([2,4,6,8,10,12,14], fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r'# of retrieved samples ($k$)', fontsize=20,labelpad=5)
plt.ylabel(r'Avg. MSE', fontsize=20,labelpad=5)
# ax[0,0].plot(df1['X'],df1['Y'],color='blue',linestyle='solid',marker='o')
# ax[0,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dotted',marker='o')
# ax[1,0].plot(df1['X'],df1['Y'],color='blue',linestyle='dashed',marker='o')
# ax[1,1].plot(df1['X'],df1['Y'],color='blue',linestyle='dashdot',marker='o')
########################################################################
# plt.tight_layout()
# plt.show()
########################################################################
plt.tight_layout()
SAVE_PATH = '/home/seunghan.lee/workspace/experiments/figures'
fn = "motivation_K2.pdf"
fn = os.path.join(SAVE_PATH,fn)
plt.savefig(fn, bbox_inches="tight")
plt.show()

# %%
'&'.join(list(filtered_base['Avg'].values[[1,3,5,7,9,11,13]].round(4).astype('str')))
# Out:
# '0.1975&0.2011&0.1968&0.1975&0.1964&0.1974&0.2013'

# %%
'&'.join(list(filtered_ours['Avg'].values[[1,3,5,7,9,11,13]].round(4).astype('str')))
# Out:
# '0.1944&0.1938&0.1936&0.1934&0.1933&0.193&0.1927'

# %%
0.1975&0.2011&0.1968&0.1975&0.1964&0.1974&0.2013
0.1944&0.1938&0.1936&0.1934&0.1933&0.193&0.1927
